# %%
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize, sent_tokenize

sentences = "Hello there! How are you doing today? This is a sample text for tokenization."
print(sent_tokenize(sentences))
print(word_tokenize(sentences))
# Out:
# ['Hello there!', 'How are you doing today?', 'This is a sample text for tokenization.']
# ['Hello', 'there', '!', 'How', 'are', 'you', 'doing', 'today', '?', 'This', 'is', 'a', 'sample', 'text', 'for', 'tokenization', '.']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ghina\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
