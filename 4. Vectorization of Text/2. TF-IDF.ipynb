# %% [markdown]
# # Term Frequency - Inverse Document Frequency
#
# term frequency - analyzes how many times a word appears in a single document
#
# inverse document frequency - analyzes how many times a word appears in a entire collection of documents
#
# common words have a lower score while unique words have a higher score as they carry more meaning or weight

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# c:\Users\ghina\anaconda3\envs\aiml_env\Lib\site-packages\sklearn\utils\_param_validation.py:14: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.4)
#   from scipy.sparse import csr_matrix, issparse

# %%
data = ['Most Shark attacks occur near the coast. It is important to be cautious while swimming in the ocean.',
        'The new movie received rave reviews from critics and audiences alike. It is a must-watch for everyone.',
        'The restaurant had poor service and the food was bland. I would not recommend it to anyone.',
        'The concert was an unforgettable experience. The band played all their hit songs and the crowd was energetic.',
        'The book was a thrilling page-turner from start to finish. The plot twists kept me on the edge of my seat.',
        'The hotel had a beautiful view of the beach and the staff were friendly and accommodating.',
        'The traffic was terrible and I was late for my appointment. I will avoid that route in the future.']

# %%
tfidfvec = TfidfVectorizer()

# %%
tfidfvec_fit = tfidfvec.fit_transform(data)

# %%
tfidf_bag = pd.DataFrame(tfidfvec_fit.toarray(), columns=tfidfvec.get_feature_names_out())

# %%
print(tfidf_bag)
# Out:
#    accommodating     alike      all       an       and    anyone  appointment  \
# 0       0.000000  0.000000  0.00000  0.00000  0.000000  0.000000     0.000000
# 1       0.000000  0.266905  0.00000  0.00000  0.144026  0.000000     0.000000
# 2       0.000000  0.000000  0.00000  0.00000  0.155328  0.287849     0.000000
# 3       0.000000  0.000000  0.25491  0.25491  0.137553  0.000000     0.000000
# 4       0.000000  0.000000  0.00000  0.00000  0.000000  0.000000     0.000000
# 5       0.287203  0.000000  0.00000  0.00000  0.309959  0.000000     0.000000
# 6       0.000000  0.000000  0.00000  0.00000  0.146439  0.000000     0.271376
#
#    attacks  audiences     avoid  ...    turner    twists  unforgettable  \
# 0  0.25745   0.000000  0.000000  ...  0.000000  0.000000        0.00000
# 1  0.00000   0.266905  0.000000  ...  0.000000  0.000000        0.00000
# 2  0.00000   0.000000  0.000000  ...  0.000000  0.000000        0.00000
# 3  0.00000   0.000000  0.000000  ...  0.000000  0.000000        0.25491
# 4  0.00000   0.000000  0.000000  ...  0.238837  0.238837        0.00000
# 5  0.00000   0.000000  0.000000  ...  0.000000  0.000000        0.00000
# 6  0.00000   0.000000  0.271376  ...  0.000000  0.000000        0.00000
#
#        view       was     watch      were    while      will     would
# 0  0.000000  0.000000  0.000000  0.000000  0.25745  0.000000  0.000000
# 1  0.000000  0.000000  0.266905  0.000000  0.00000  0.000000  0.000000
# 2  0.000000  0.177320  0.000000  0.000000  0.00000  0.000000  0.287849
# 3  0.000000  0.314059  0.000000  0.000000  0.00000  0.000000  0.000000
# 4  0.000000  0.147128  0.000000  0.000000  0.00000  0.000000  0.000000
# 5  0.287203  0.000000  0.000000  0.287203  0.00000  0.000000  0.000000
# 6  0.000000  0.334346  0.000000  0.000000  0.00000  0.271376  0.000000
#
# [7 rows x 86 columns]
